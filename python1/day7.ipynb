# %% [markdown]
# # Set

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}

# %% [markdown]
# ## Operations

# %%
# my_set.add("orange")
# my_set.remove(4)
# 3 in my_set
# len(my_set)
# my_set.clear()

# %%
print(A.union(B)) 
print(A | B)
print(A.intersection(B))
print(A & B)
print(A.difference(B))
print(A - B)
print(A.symmetric_difference(B))
print(A ^ B)

# %%
class_A = ["Anna", "Elsa", "Olaf"]
class_B = ["Olaf", "Kristoff", "Sven"]

# %% [markdown]
# Asks uses for input
# Finds the vowels appear in sentence
# prints out the vowels
#
# Input : Hello world
# Output : {'e', 'o'}

# %% [markdown]
# Asks for input
# Check winning if it match the input
# Print matching number(s)
#
# winning = {22, 27, 58, 123, 789}
#
# input : 12, 74, 22, 50, 788
# Output : matched 22
