# %%
age = 10
name = "Alice"
is_student = True

# %% [markdown]
# numbers
# int = whole number 123 2
# float = decimal point 1.2 3.7
# complex(rare)

# %%
age = 2
print(type(age))
# Out:
# <class 'int'>

# %% [markdown]
# string(str)
# '', ""

# %% [markdown]
# Boolean(bool)
# True or False
# 1 or 0

# %% [markdown]
# collections
# list
# tuple
# dict
# set

# %% [markdown]
# Arithmetic operators
# + - * / // % **

# %% [markdown]
# comparison operators
# > < = != == <= >=

# %% [markdown]
# logical operators
# and or not

# %% [markdown]
# string operations

# %% [markdown]
# type casting

# %%
# Out:
# <class 'int'>
